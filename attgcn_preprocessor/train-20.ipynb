# %% [markdown]
# # Graph Neural Network for multiscale solver in the Traveling Salesman Problem
#
# This notebook is designed to predict the edge's probability belongs to optimized solution.
#
# In general, the input of GNN contains cooordinate($n_i \in R^{2}$), edges values(distance) and targeted edges, and meanwhile our GNN consists of $30$ graph convolutional layers and $3$ layers in MLP with hidden dimension $h=300$ for each layers.

# %%
import os

import numpy as np

import torch
print(torch.cuda.is_available())
from config import *
from utils.process import *
# Out:
# True

# %% [markdown]
# ## 1. Set the model configuration parameters
#
# The cell below sets a number of parameters that define the model configuration. The parameters set here are being used both by the `get_config()` function.

# %%
notebook_mode = True
viz_mode = False

# model-parameter
# config_path = "configs/tsp20.json"
config_path = "configs/tsp10.json"
config = get_config(config_path)

# %% [markdown]
# ## 2. Build or load the model
#
# You will want to execute either of the two code cells in the subsequent two sub-sections, not both.

# %% [markdown]
# ### 2.1 Create a new model
#
# If you want to create a new model, this is the relevant section for you. If you want to load a previously saved model, skip ahead to section 2.2.

# %%
if viz_mode==False:

    # tsp20--model
    net = main(config, pretrained=False, patience=50, lr_scale=0.001, random_neighbor=False)
# Out:
# DataParallel(
#   (module): ResidualGatedGCNModel(
#     (nodes_coord_embedding): Linear(in_features=2, out_features=300, bias=False)
#     (edges_values_embedding): Linear(in_features=1, out_features=150, bias=False)
#     (edges_embedding): Embedding(3, 150)
#     (gcn_layers): ModuleList(
#       (0): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (1): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (2): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (3): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (4): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (5): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (6): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (7): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (8): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (9): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (10): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (11): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (12): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (13): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (14): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (15): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (16): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (17): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (18): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (19): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (20): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (21): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (22): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (23): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (24): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (25): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (26): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (27): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (28): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#       (29): ResidualGatedGCNLayer(
#         (node_feat): NodeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (edge_feat): EdgeFeatures(
#           (U): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#           (V): Conv1d(300, 300, kernel_size=(1,), stride=(1,))
#         )
#         (bn_node): BatchNormNode(
#           (batch_norm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#         (bn_edge): BatchNormEdge(
#           (batch_norm): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#         )
#       )
#     )
#     (mlp_edges): MLP(
#       (U): ModuleList(
#         (0): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#         (1): Conv1d(300, 300, kernel_size=(1, 1), stride=(1,))
#       )
#       (V): Conv1d(300, 2, kernel_size=(1, 1), stride=(1,))
#     )
#   )
# )
# Number of parameters: 11054402
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 1e-06
#     weight_decay: 0
# )
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='30' class='' max='1500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       2.00% [30/1500 36:07<29:30:15]
#     </div>
#
# t: epoch:00	time:0.0h	lr:1.00e-06	loss:0.2647	pred_tour_len:8.478	gt_tour_len:2.858	num_neighbors:09<p>v: epoch:00	time:0.0h	lr:1.00e-06	loss:0.2011	pred_tour_len:2.989	gt_tour_len:2.872	num_neighbors:09<p>t: epoch:01	time:0.0h	lr:1.00e-06	loss:0.1786	pred_tour_len:4.582	gt_tour_len:2.854	num_neighbors:09<p>t: epoch:02	time:0.0h	lr:1.00e-06	loss:0.1612	pred_tour_len:4.417	gt_tour_len:2.854	num_neighbors:09<p>t: epoch:03	time:0.0h	lr:1.00e-06	loss:0.1536	pred_tour_len:4.385	gt_tour_len:2.854	num_neighbors:09<p>t: epoch:04	time:0.0h	lr:1.00e-06	loss:0.1472	pred_tour_len:4.362	gt_tour_len:2.854	num_neighbors:09<p>t: epoch:05	time:0.0h	lr:1.00e-06	loss:0.1430	pred_tour_len:4.354	gt_tour_len:2.864	num_neighbors:09<p>v: epoch:05	time:0.0h	lr:1.00e-06	loss:0.1410	pred_tour_len:2.969	gt_tour_len:2.872	num_neighbors:09<p>t: epoch:06	time:0.0h	lr:1.00e-06	loss:0.1395	pred_tour_len:4.321	gt_tour_len:2.861	num_neighbors:09<p>t: epoch:07	time:0.0h	lr:1.00e-06	loss:0.1367	pred_tour_len:4.308	gt_tour_len:2.858	num_neighbors:09<p>t: epoch:08	time:0.0h	lr:1.00e-06	loss:0.1351	pred_tour_len:4.289	gt_tour_len:2.857	num_neighbors:09<p>t: epoch:09	time:0.0h	lr:1.00e-06	loss:0.1322	pred_tour_len:4.280	gt_tour_len:2.858	num_neighbors:09<p>t: epoch:10	time:0.0h	lr:1.00e-06	loss:0.1311	pred_tour_len:4.256	gt_tour_len:2.851	num_neighbors:09<p>v: epoch:10	time:0.0h	lr:1.00e-06	loss:0.1300	pred_tour_len:2.955	gt_tour_len:2.872	num_neighbors:09<p>t: epoch:11	time:0.0h	lr:1.00e-06	loss:0.1298	pred_tour_len:4.264	gt_tour_len:2.858	num_neighbors:09<p>t: epoch:12	time:0.0h	lr:1.00e-06	loss:0.1276	pred_tour_len:4.243	gt_tour_len:2.851	num_neighbors:09<p>t: epoch:13	time:0.0h	lr:1.00e-06	loss:0.1258	pred_tour_len:4.254	gt_tour_len:2.863	num_neighbors:09<p>t: epoch:14	time:0.0h	lr:1.00e-06	loss:0.1240	pred_tour_len:4.244	gt_tour_len:2.862	num_neighbors:09<p>t: epoch:15	time:0.0h	lr:1.00e-06	loss:0.1226	pred_tour_len:4.211	gt_tour_len:2.855	num_neighbors:09<p>v: epoch:15	time:0.0h	lr:1.00e-06	loss:0.1215	pred_tour_len:2.946	gt_tour_len:2.872	num_neighbors:09<p>t: epoch:16	time:0.0h	lr:1.00e-06	loss:0.1207	pred_tour_len:4.208	gt_tour_len:2.858	num_neighbors:09<p>t: epoch:17	time:0.0h	lr:1.00e-06	loss:0.1181	pred_tour_len:4.170	gt_tour_len:2.853	num_neighbors:09<p>t: epoch:18	time:0.0h	lr:1.00e-06	loss:0.1172	pred_tour_len:4.176	gt_tour_len:2.857	num_neighbors:09<p>t: epoch:19	time:0.0h	lr:1.00e-06	loss:0.1159	pred_tour_len:4.180	gt_tour_len:2.862	num_neighbors:09<p>t: epoch:20	time:0.0h	lr:1.00e-06	loss:0.1146	pred_tour_len:4.160	gt_tour_len:2.859	num_neighbors:09<p>v: epoch:20	time:0.0h	lr:1.00e-06	loss:0.1133	pred_tour_len:2.938	gt_tour_len:2.872	num_neighbors:09<p>t: epoch:21	time:0.0h	lr:1.00e-06	loss:0.1136	pred_tour_len:4.146	gt_tour_len:2.856	num_neighbors:09<p>t: epoch:22	time:0.0h	lr:1.00e-06	loss:0.1117	pred_tour_len:4.135	gt_tour_len:2.858	num_neighbors:09<p>t: epoch:23	time:0.0h	lr:1.00e-06	loss:0.1106	pred_tour_len:4.116	gt_tour_len:2.851	num_neighbors:09<p>t: epoch:24	time:0.0h	lr:1.00e-06	loss:0.1098	pred_tour_len:4.110	gt_tour_len:2.857	num_neighbors:09<p>t: epoch:25	time:0.0h	lr:1.00e-06	loss:0.1082	pred_tour_len:4.088	gt_tour_len:2.852	num_neighbors:09<p>v: epoch:25	time:0.0h	lr:1.00e-06	loss:0.1075	pred_tour_len:2.934	gt_tour_len:2.872	num_neighbors:09<p>t: epoch:26	time:0.0h	lr:1.00e-06	loss:0.1067	pred_tour_len:4.079	gt_tour_len:2.858	num_neighbors:09<p>t: epoch:27	time:0.0h	lr:1.00e-06	loss:0.1066	pred_tour_len:4.082	gt_tour_len:2.856	num_neighbors:09<p>t: epoch:28	time:0.0h	lr:1.00e-06	loss:0.1042	pred_tour_len:4.046	gt_tour_len:2.856	num_neighbors:09<p>t: epoch:29	time:0.0h	lr:1.00e-06	loss:0.1052	pred_tour_len:4.064	gt_tour_len:2.861	num_neighbors:09<p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='151' class='' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       30.20% [151/500 00:21<00:48 loss:0.1033 pred_tour_len:4.053 gt_tour_len:2.853]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8881/2233320164.py in <module>
#       2
#       3     # tsp20--model
# ----> 4     net = main(config, pretrained=False, patience=50, lr_scale=0.001, random_neighbor=False)
#
# /home/FINDER-TSP/attgcn_preprocessor/utils/process.py in main(config, pretrained, patience, lr_scale, pretrained_path, var_neighbor, random_neighbor, netname)
#     349
#     350         # Train
# --> 351         train_time, train_loss, train_err_edges, train_err_tour, train_err_tsp, train_pred_tour_len, train_gt_tour_len = train_one_epoch(net, optimizer, config, epoch_bar, num_neighbors)
#     352         epoch_bar.write('t: ' + metrics_to_str(epoch, train_time, learning_rate, train_loss, train_err_edges, train_err_tour, train_err_tsp, train_pred_tour_len, train_gt_tour_len, num_neighbors))
#     353         writer.add_scalar('loss/train_loss', train_loss, epoch)
#
# /home/FINDER-TSP/attgcn_preprocessor/utils/process.py in train_one_epoch(net, optimizer, config, master_bar, num_neighbors)
#     100         # Forward pass
#     101         y_preds, loss = net.forward(x_edges, x_edges_values, x_nodes, x_nodes_coord, y_edges,
# --> 102                                     edge_cw, num_neg, loss_type, gamma)
#     103         loss = loss.mean()  # Take mean of loss across multiple GPUs
#     104         loss = loss / accumulation_steps  # Scale loss by accumulation steps
#
# ~/miniconda3/envs/finderenv_new/lib/python3.7/site-packages/torch/nn/parallel/data_parallel.py in forward(self, *inputs, **kwargs)
#     139         inputs, kwargs = self.scatter(inputs, kwargs, self.device_ids)
#     140         if len(self.device_ids) == 1:
# --> 141             return self.module(*inputs[0], **kwargs[0])
#     142         replicas = self.replicate(self.module, self.device_ids[:len(inputs)])
#     143         outputs = self.parallel_apply(replicas, inputs, kwargs)
#
# ~/miniconda3/envs/finderenv_new/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /home/FINDER-TSP/attgcn_preprocessor/models/gcn_model.py in forward(self, x_edges, x_edges_values, x_nodes, x_nodes_coord, y_edges, edge_cw, num_neg, loss_type, gamma)
#      73         # GCN layers
#      74         for layer in range(self.num_layers):
# ---> 75             x, e = self.gcn_layers[layer](x, e)  # B x V x H, B x V x V x H
#      76         # MLP classifier
#      77         y_pred_edges = self.mlp_edges(e)  # B x V x V x voc_edges_out
#
# ~/miniconda3/envs/finderenv_new/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# /home/FINDER-TSP/attgcn_preprocessor/models/gcn_layers.py in forward(self, x, e)
#     143         x_tmp = self.bn_node(x_tmp)
#     144         # ReLU Activation
# --> 145         e = F.relu(e_tmp)
#     146         x = F.relu(x_tmp)
#     147         # Residual connection
#
# ~/miniconda3/envs/finderenv_new/lib/python3.7/site-packages/torch/nn/functional.py in relu(input, inplace)
#     860         result = torch.relu_(input)
#     861     else:
# --> 862         result = torch.relu(input)
#     863     return result
#     864
#
# KeyboardInterrupt:

# %% [markdown]
# ### 2.2 Load a saved model
#
# If you have previously created and saved a model and would now like to load it, simply execute the next code cell.

# %%
if viz_mode==False:

    # tsp20--model
    net = main(config, pretrained=True, patience=50,
               lr_scale=0.01, pretrained_path='./logs/tsp20/attgcn_preprocessor-2020-02-17 01:14:40/best_val_checkpoint.tar',
               random_neighbor=False)
